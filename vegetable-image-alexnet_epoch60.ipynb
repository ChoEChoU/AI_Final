# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_path = "../input/vegetable-image-dataset/Vegetable Images/train"
validation_path = "../input/vegetable-image-dataset/Vegetable Images/validation"
test_path = "../input/vegetable-image-dataset/Vegetable Images/test"

# %%
from matplotlib import image
from PIL import Image

def Load_Images(path):
    folders=os.listdir(path)
    data = []
    label = []
    print(folders)
    for i in folders:
        c=0
        images=os.listdir(path + '/' + i)
        for j in images:
            c+=1
            im=Image.open(path + '/' + i + '/' + j).convert('RGB')
            im=im.resize((224,224), image.NEAREST)
            #print(im.size)
            ar=np.array(im)
            #print(ar.shape)
            data.append(ar)
            if i=='Bean':
                label.append(i)
            elif i=='Bitter_Gourd':
                label.append(i)
            elif i=='Bottle':
                label.append(i)
            elif i=='Brinjal':
                label.append(i)
            elif i=='Broccoli':
                label.append(i)
            elif i=='Cabbage':
                label.append(i)
            elif i=='Capsicum':
                label.append(i)
            elif i=='Carrot':
                label.append(i)
            elif i=='Cauliflower':
                label.append(i)
            elif i=='Cucumber':
                label.append(i)
            elif i=='Papaya':
                label.append(i)
            elif i=='Potato':
                label.append(i)
            elif i=='Pumpkin':
                label.append(i)
            elif i=='Radish':
                label.append(i)
            else:
                label.append(i)
            #label.append(i)
            #print(c)
    t=pd.factorize(np.array(label))
    print(t)
    tgt=t[0]
    return np.array(data), tgt

# %%
x_train, y_train = Load_Images(train_path)
y_train = pd.Series(y_train)
print(x_train.shape)
# Out:
# ['Broccoli', 'Capsicum', 'Bottle_Gourd', 'Radish', 'Tomato', 'Brinjal', 'Pumpkin', 'Carrot', 'Papaya', 'Cabbage', 'Bitter_Gourd', 'Cauliflower', 'Bean', 'Cucumber', 'Potato']
# (array([ 0,  0,  0, ..., 14, 14, 14]), array(['Broccoli', 'Capsicum', 'Bottle_Gourd', 'Radish', 'Tomato',
#        'Brinjal', 'Pumpkin', 'Carrot', 'Papaya', 'Cabbage',
#        'Bitter_Gourd', 'Cauliflower', 'Bean', 'Cucumber', 'Potato'],
#       dtype=object))
# (15000, 224, 224, 3)

# %%
x_valid, y_valid = Load_Images(validation_path)
y_valid = pd.Series(y_valid)
print(x_valid.shape)
# Out:
# ['Broccoli', 'Capsicum', 'Bottle_Gourd', 'Radish', 'Tomato', 'Brinjal', 'Pumpkin', 'Carrot', 'Papaya', 'Cabbage', 'Bitter_Gourd', 'Cauliflower', 'Bean', 'Cucumber', 'Potato']
# (array([ 0,  0,  0, ..., 14, 14, 14]), array(['Broccoli', 'Capsicum', 'Bottle_Gourd', 'Radish', 'Tomato',
#        'Brinjal', 'Pumpkin', 'Carrot', 'Papaya', 'Cabbage',
#        'Bitter_Gourd', 'Cauliflower', 'Bean', 'Cucumber', 'Potato'],
#       dtype=object))
# (3000, 224, 224, 3)

# %%
name_list = ['Bean', 'Bitter_Gourd', 'Bottle_Gourd', 'Brinjal', 'Broccoli', 'Cabbage', 'Capsicum', 'Carrot', 'Cauliflower', 'Cucumber', 'Papaya', 'Potato', 'Pumpkin', 'Radish', 'Tomato']
index = 0
for i in name_list:
    y_train = y_train.replace(i, index)
    y_valid = y_valid.replace(i, index)
    index += 1

# %%
x_test, y_test = Load_Images(test_path)
y_test = pd.Series(y_test)
y_test = y_test.replace("Bean", 0)
y_test = y_test.replace("Bitter_Gourd", 1)
y_test = y_test.replace("Bottle_Gourd", 2)
y_test = y_test.replace("Brinjal", 3)
y_test = y_test.replace("Broccoli", 4)
y_test = y_test.replace("Cabbage", 5)
y_test = y_test.replace("Capsicum", 6)
y_test = y_test.replace("Carrot", 7)
y_test = y_test.replace("Cauliflower", 8)
y_test = y_test.replace("Cucumber", 9)
y_test = y_test.replace("Papaya", 10)
y_test = y_test.replace("Potato", 11)
y_test = y_test.replace("Pumpkin", 12)
y_test = y_test.replace("Radish", 13)
y_test = y_test.replace("Tomato", 14)
# Out:
# ['Broccoli', 'Capsicum', 'Bottle_Gourd', 'Radish', 'Tomato', 'Brinjal', 'Pumpkin', 'Carrot', 'Papaya', 'Cabbage', 'Bitter_Gourd', 'Cauliflower', 'Bean', 'Cucumber', 'Potato']
# (array([ 0,  0,  0, ..., 14, 14, 14]), array(['Broccoli', 'Capsicum', 'Bottle_Gourd', 'Radish', 'Tomato',
#        'Brinjal', 'Pumpkin', 'Carrot', 'Papaya', 'Cabbage',
#        'Bitter_Gourd', 'Cauliflower', 'Bean', 'Cucumber', 'Potato'],
#       dtype=object))

# %%
# # 1. Train Set

# # rescale: 0과 1사이로 값을 변경함
# # ImageDataGenerator: 데이터 증식(augmentation)
# # ImageDataGenerator는 Noise삽입, 색상, 밝기 변형 등을 활용하여 실시간으로 데이터 증강을 사용하고, 
# # 텐서 이미지 데이터 배치를 생성하여 데이터 학습의 정확도를 높이는 역할을 한다.

# train_gen = ImageDataGenerator(rescale = 1./255.0) # Normalise the data

# # flow() 또는 flow_from_directory() 또는 flow_from_dataframe() 함수로 Numpy Array Iterator 객체를 만들어줌. 
# # 이 때, X(image) array, Y(label) array, 배치 사이즈, 데이터 셔플 유무를 설정.

# # 메타 데이터:  이미지 데이터 파일(jpg, jpeg)들과 해당 이미지들이 무슨 이미지를 나타내는지 텍스트로 표현한 문자열(cat, dog와 같은 문자열들)
# # flow_from_directory(): 메타 데이터가 담긴 디렉토리
# # target_size : 추후에 설계할 모델에 들어갈 인풋 이미지 사이즈 중 Width, Height를 입력
# # batch_size : 이미지 데이터 원본 소스에서 한 번에 얼마만큼의 이미지 데이터를 가져올 것인지
# # class_mode
# #    'categorical' : 'categorical_crossentropy' 처럼 멀티-레이블 클래스인데, 원-핫 인코딩된 형태
# #    'sparse' : 'sparse_categorical_crossentropy' 처럼 멀티-레이블 클래스인데, 레이블 인코딩된 형태
# #    'binary' : 'binary_crossentropy' 처럼 이진 분류 클래스로, 0 또는 1인 형태

# train_image_generator = train_gen.flow_from_directory(
#                                             train_path,
#                                             target_size=(224, 224),
#                                             batch_size=32,
#                                             class_mode='categorical')

# # 2. Validation Set
# val_gen = ImageDataGenerator(rescale = 1.0/255.0) # Normalise the data
# val_image_generator = train_gen.flow_from_directory(
#                                             validation_path,
#                                             target_size=(224, 224),
#                                             batch_size=32,
#                                             class_mode='categorical')

# # 3. Test Set
# test_gen = ImageDataGenerator(rescale = 1.0/255.0) # Normalise the data
# test_image_generator = train_gen.flow_from_directory(
#                                             test_path,
#                                             target_size=(224, 224),
#                                             batch_size=32,
#                                             class_mode='categorical')

# %%
# from keras.preprocessing import image
# # Call the function
# image_categories = os.listdir('../input/vegetable-image-dataset/Vegetable Images/train')

# def plot_images(image_categories):
#     # Create a figure
#     plt.figure(figsize=(12, 12))
#     for i, cat in enumerate(image_categories):
#         # Load images for the ith category
#         image_path = train_path + '/' + cat
#         images_in_folder = os.listdir(image_path)
#         first_image_of_folder = images_in_folder[0]
#         first_image_path = image_path + '/' + first_image_of_folder
#         img = image.load_img(first_image_path)
#         img_arr = image.img_to_array(img)/255.0

#         # Create Subplot and plot the images
#         plt.subplot(4, 4, i+1)
#         plt.imshow(img_arr)
#         plt.title(cat)
#         plt.axis('off')

#     plt.show()

# # Call the function
# plot_images(image_categories)

# %%
# from keras.models import Sequential 
# from keras.layers import Conv2D,Dense, Flatten, AveragePooling2D, Dropout 
# model = Sequential()

# model.add(Conv2D(6, kernel_size=(3, 3), activation='tanh', input_shape=x_train.shape[1:]))
# model.add(AveragePooling2D())
# Dropout(0.2)

# model.add(Conv2D(32, kernel_size=(3,3), activation='tanh'))
# model.add(AveragePooling2D())

# model.add(Conv2D(64, kernel_size=(3,3),activation='tanh'))

# model.add(Flatten())

# model.add(Dense(15, activation = 'softmax'))
# model.summary()

# %%
import tensorflow as tf
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# %%
from keras.models import Sequential 
from keras.layers import Input,Conv2D, Dense, Flatten, MaxPooling2D, Dropout, BatchNormalization, Activation, ZeroPadding2D
model = Sequential()

# 논문을 바탕으로 모델 구축함.
# 그러나 Computing power 한계로 인해 변경을 좀 했음.
# modeling
# input_shape = (224, 224, 3)  # 논문에서 제시된 shape

img_shape = x_train.shape[1:]

# CONV
# 레이어 1
model.add(Conv2D(filters=96, kernel_size=11, activation='relu', strides=4, padding='same',input_shape=img_shape))
model.add(MaxPooling2D((3,3), strides=2)) # overlapped pooling
model.add(BatchNormalization())

# 레이어 2
model.add(Conv2D(filters=256, kernel_size=5, activation='relu', strides=1, padding='same'))
model.add(MaxPooling2D((3,3), strides=2))
model.add(BatchNormalization())

# 레이어 3
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(filters=384, kernel_size=3, activation='relu', strides=1, padding='same'))

# 레이어 4
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(filters=384, kernel_size=3, activation='relu', strides=1, padding='same'))

# 레이어 5
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(filters=256, kernel_size=3, activation='relu', strides=1, padding='same'))
model.add(MaxPooling2D((3,3), strides=2))

# FC
# 레이어 6
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))  # 논문 parameter 0.5 이용함.

# 레이어 7
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

# 레이어 8
model.add(Dense(1000, activation='softmax'))
model.summary()
# Out:
# 2022-12-04 16:02:58.054170: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:02:58.055253: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:02:58.193591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:02:58.194589: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:02:58.195393: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:02:58.196185: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:02:58.198360: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-04 16:02:58.448134: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:02:58.449096: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:02:58.449874: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:02:58.450639: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:02:58.451437: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:02:58.452235: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:03:00.913328: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:03:00.914296: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:03:00.915119: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:03:00.915869: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:03:00.916620: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:03:00.917343: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-12-04 16:03:00.917852: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:03:00.918575: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 56, 56, 96)        34944
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 27, 27, 96)        384
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 27, 256)       614656
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 256)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 13, 13, 256)       1024
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 15, 15, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 384)       885120
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 17, 17, 384)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 17, 17, 384)       1327488
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 19, 19, 384)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 19, 19, 256)       884992
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 20736)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              84938752
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              4097000
# =================================================================
# Total params: 109,565,672
# Trainable params: 109,564,968
# Non-trainable params: 704
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping
history = model.fit(x_train, y_train, epochs=60,  validation_data=(x_valid, y_valid))
# Out:
# 2022-12-04 16:03:01.622944: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 2257920000 exceeds 10% of free system memory.
# 2022-12-04 16:03:04.347713: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 2257920000 exceeds 10% of free system memory.
# 2022-12-04 16:03:06.448660: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/60
# 2022-12-04 16:03:07.890595: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 469/469 [==============================] - 38s 67ms/step - loss: 1.9008 - accuracy: 0.4501 - val_loss: 1.3128 - val_accuracy: 0.6063
# Epoch 2/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.9001 - accuracy: 0.7252 - val_loss: 0.7382 - val_accuracy: 0.7850
# Epoch 3/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.6657 - accuracy: 0.8037 - val_loss: 0.6998 - val_accuracy: 0.7807
# Epoch 4/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.5298 - accuracy: 0.8457 - val_loss: 0.9778 - val_accuracy: 0.7570
# Epoch 5/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.4897 - accuracy: 0.8663 - val_loss: 0.7688 - val_accuracy: 0.8120
# Epoch 6/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.4622 - accuracy: 0.8745 - val_loss: 0.4610 - val_accuracy: 0.8667
# Epoch 7/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.3488 - accuracy: 0.9057 - val_loss: 2.7812 - val_accuracy: 0.4510
# Epoch 8/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.3219 - accuracy: 0.9111 - val_loss: 0.9356 - val_accuracy: 0.7853
# Epoch 9/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.3168 - accuracy: 0.9198 - val_loss: 0.3312 - val_accuracy: 0.9110
# Epoch 10/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2855 - accuracy: 0.9249 - val_loss: 0.2880 - val_accuracy: 0.9207
# Epoch 11/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2594 - accuracy: 0.9306 - val_loss: 1.7156 - val_accuracy: 0.5887
# Epoch 12/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.3217 - accuracy: 0.9219 - val_loss: 0.2023 - val_accuracy: 0.9433
# Epoch 13/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2250 - accuracy: 0.9416 - val_loss: 0.3136 - val_accuracy: 0.9150
# Epoch 14/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2407 - accuracy: 0.9395 - val_loss: 0.3926 - val_accuracy: 0.9110
# Epoch 15/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2166 - accuracy: 0.9428 - val_loss: 0.2148 - val_accuracy: 0.9460
# Epoch 16/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2380 - accuracy: 0.9429 - val_loss: 0.2783 - val_accuracy: 0.9340
# Epoch 17/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2446 - accuracy: 0.9417 - val_loss: 0.4483 - val_accuracy: 0.8967
# Epoch 18/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2504 - accuracy: 0.9415 - val_loss: 0.2374 - val_accuracy: 0.9473
# Epoch 19/60
# 469/469 [==============================] - 31s 66ms/step - loss: 0.1963 - accuracy: 0.9527 - val_loss: 0.2431 - val_accuracy: 0.9483
# Epoch 20/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1782 - accuracy: 0.9587 - val_loss: 0.7932 - val_accuracy: 0.8287
# Epoch 21/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2163 - accuracy: 0.9523 - val_loss: 0.2443 - val_accuracy: 0.9417
# Epoch 22/60
# 469/469 [==============================] - 30s 65ms/step - loss: 0.2177 - accuracy: 0.9513 - val_loss: 0.8903 - val_accuracy: 0.8380
# Epoch 23/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2452 - accuracy: 0.9463 - val_loss: 0.2499 - val_accuracy: 0.9393
# Epoch 24/60
# 469/469 [==============================] - 30s 65ms/step - loss: 0.1982 - accuracy: 0.9535 - val_loss: 0.1503 - val_accuracy: 0.9630
# Epoch 25/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1794 - accuracy: 0.9590 - val_loss: 0.2579 - val_accuracy: 0.9427
# Epoch 26/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1896 - accuracy: 0.9583 - val_loss: 0.3088 - val_accuracy: 0.9357
# Epoch 27/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2229 - accuracy: 0.9575 - val_loss: 0.1911 - val_accuracy: 0.9567
# Epoch 28/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1958 - accuracy: 0.9591 - val_loss: 0.2204 - val_accuracy: 0.9547
# Epoch 29/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1382 - accuracy: 0.9704 - val_loss: 0.6047 - val_accuracy: 0.9057
# Epoch 30/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1839 - accuracy: 0.9639 - val_loss: 0.2294 - val_accuracy: 0.9460
# Epoch 31/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1918 - accuracy: 0.9603 - val_loss: 0.2405 - val_accuracy: 0.9450
# Epoch 32/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1486 - accuracy: 0.9678 - val_loss: 0.5495 - val_accuracy: 0.8947
# Epoch 33/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1746 - accuracy: 0.9650 - val_loss: 0.3648 - val_accuracy: 0.9300
# Epoch 34/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1837 - accuracy: 0.9649 - val_loss: 0.1828 - val_accuracy: 0.9650
# Epoch 35/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1620 - accuracy: 0.9682 - val_loss: 0.1886 - val_accuracy: 0.9640
# Epoch 36/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1460 - accuracy: 0.9695 - val_loss: 0.3158 - val_accuracy: 0.9337
# Epoch 37/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2396 - accuracy: 0.9573 - val_loss: 0.1975 - val_accuracy: 0.9583
# Epoch 38/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1453 - accuracy: 0.9704 - val_loss: 0.4299 - val_accuracy: 0.9290
# Epoch 39/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1634 - accuracy: 0.9703 - val_loss: 0.1622 - val_accuracy: 0.9653
# Epoch 40/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1792 - accuracy: 0.9698 - val_loss: 0.1741 - val_accuracy: 0.9603
# Epoch 41/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1717 - accuracy: 0.9707 - val_loss: 0.2691 - val_accuracy: 0.9577
# Epoch 42/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1956 - accuracy: 0.9683 - val_loss: 0.2070 - val_accuracy: 0.9617
# Epoch 43/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1522 - accuracy: 0.9699 - val_loss: 0.4105 - val_accuracy: 0.9227
# Epoch 44/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1480 - accuracy: 0.9746 - val_loss: 0.2094 - val_accuracy: 0.9517
# Epoch 45/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1350 - accuracy: 0.9727 - val_loss: 0.2421 - val_accuracy: 0.9537
# Epoch 46/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1833 - accuracy: 0.9681 - val_loss: 0.2374 - val_accuracy: 0.9580
# Epoch 47/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1286 - accuracy: 0.9751 - val_loss: 0.2154 - val_accuracy: 0.9477
# Epoch 48/60
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1570 - accuracy: 0.9720 - val_loss: 0.2920 - val_accuracy: 0.9367
# Epoch 49/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1448 - accuracy: 0.9749 - val_loss: 0.6644 - val_accuracy: 0.8927
# Epoch 50/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1784 - accuracy: 0.9701 - val_loss: 0.2759 - val_accuracy: 0.9550
# Epoch 51/60
# 469/469 [==============================] - 30s 65ms/step - loss: 0.1731 - accuracy: 0.9699 - val_loss: 9.6378 - val_accuracy: 0.5513
# Epoch 52/60
# 469/469 [==============================] - 30s 65ms/step - loss: 0.1874 - accuracy: 0.9696 - val_loss: 0.2027 - val_accuracy: 0.9630
# Epoch 53/60
# 469/469 [==============================] - 31s 66ms/step - loss: 0.1230 - accuracy: 0.9791 - val_loss: 0.2642 - val_accuracy: 0.9593
# Epoch 54/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1419 - accuracy: 0.9765 - val_loss: 0.2746 - val_accuracy: 0.9593
# Epoch 55/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1519 - accuracy: 0.9752 - val_loss: 0.4496 - val_accuracy: 0.9440
# Epoch 56/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1824 - accuracy: 0.9725 - val_loss: 0.2363 - val_accuracy: 0.9697
# Epoch 57/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1208 - accuracy: 0.9785 - val_loss: 0.2332 - val_accuracy: 0.9557
# Epoch 58/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1502 - accuracy: 0.9751 - val_loss: 0.6203 - val_accuracy: 0.8953
# Epoch 59/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1062 - accuracy: 0.9803 - val_loss: 0.1946 - val_accuracy: 0.9663
# Epoch 60/60
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1577 - accuracy: 0.9747 - val_loss: 0.3338 - val_accuracy: 0.9293

# %%
# hist = model.fit(train_image_generator, 
#                  epochs=20, 
#                  verbose=1, 
#                  validation_data=val_image_generator, 
#                  steps_per_epoch = 15000//24, 
#                  validation_steps = 3000//24)

# h = hist.history
# plt.style.use('ggplot')
# plt.figure(figsize=(10, 5))
# plt.plot(h['loss'], c='red', label='Training Loss')
# plt.plot(h['val_loss'], c='red', linestyle='--', label='Validation Loss')
# plt.plot(h['accuracy'], c='blue', label='Training Accuracy')
# plt.plot(h['val_accuracy'], c='blue', linestyle='--', label='Validation Accuracy')
# plt.xlabel("Number of Epochs")
# plt.legend(loc='best')
# plt.show()

# model.evaluate(test_image_generator)

# %%
history_df = pd.DataFrame(history.history)
history_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.900797  0.450133  1.312841      0.606333
# 1   0.900119  0.725200  0.738213      0.785000
# 2   0.665735  0.803667  0.699781      0.780667
# 3   0.529844  0.845667  0.977842      0.757000
# 4   0.489696  0.866333  0.768818      0.812000
# 5   0.462235  0.874533  0.460972      0.866667
# 6   0.348824  0.905667  2.781201      0.451000
# 7   0.321866  0.911067  0.935629      0.785333
# 8   0.316789  0.919800  0.331243      0.911000
# 9   0.285497  0.924933  0.288008      0.920667
# 10  0.259384  0.930600  1.715626      0.588667
# 11  0.321723  0.921867  0.202275      0.943333
# 12  0.225018  0.941600  0.313567      0.915000
# 13  0.240658  0.939533  0.392621      0.911000
# 14  0.216644  0.942800  0.214830      0.946000
# 15  0.238016  0.942933  0.278273      0.934000
# 16  0.244577  0.941733  0.448331      0.896667
# 17  0.250444  0.941467  0.237382      0.947333
# 18  0.196269  0.952667  0.243133      0.948333
# 19  0.178244  0.958667  0.793228      0.828667
# 20  0.216301  0.952333  0.244337      0.941667
# 21  0.217712  0.951333  0.890263      0.838000
# 22  0.245202  0.946333  0.249932      0.939333
# 23  0.198157  0.953467  0.150328      0.963000
# 24  0.179443  0.959000  0.257920      0.942667
# 25  0.189606  0.958333  0.308813      0.935667
# 26  0.222908  0.957467  0.191057      0.956667
# 27  0.195806  0.959133  0.220357      0.954667
# 28  0.138186  0.970400  0.604663      0.905667
# 29  0.183883  0.963933  0.229387      0.946000
# 30  0.191845  0.960267  0.240492      0.945000
# 31  0.148579  0.967800  0.549523      0.894667
# 32  0.174575  0.965000  0.364784      0.930000
# 33  0.183746  0.964867  0.182755      0.965000
# 34  0.161976  0.968200  0.188572      0.964000
# 35  0.146010  0.969467  0.315806      0.933667
# 36  0.239611  0.957333  0.197516      0.958333
# 37  0.145258  0.970400  0.429852      0.929000
# 38  0.163393  0.970333  0.162194      0.965333
# 39  0.179243  0.969800  0.174117      0.960333
# 40  0.171673  0.970667  0.269122      0.957667
# 41  0.195630  0.968333  0.207006      0.961667
# 42  0.152198  0.969933  0.410500      0.922667
# 43  0.148003  0.974600  0.209432      0.951667
# 44  0.134986  0.972667  0.242116      0.953667
# 45  0.183305  0.968133  0.237414      0.958000
# 46  0.128574  0.975067  0.215379      0.947667
# 47  0.157015  0.972000  0.291999      0.936667
# 48  0.144778  0.974933  0.664443      0.892667
# 49  0.178395  0.970133  0.275875      0.955000
# 50  0.173081  0.969933  9.637791      0.551333
# 51  0.187448  0.969600  0.202747      0.963000
# 52  0.122952  0.979133  0.264177      0.959333
# 53  0.141900  0.976533  0.274639      0.959333
# 54  0.151923  0.975200  0.449632      0.944000
# 55  0.182387  0.972533  0.236281      0.969667
# 56  0.120774  0.978467  0.233203      0.955667
# 57  0.150241  0.975067  0.620340      0.895333
# 58  0.106248  0.980267  0.194638      0.966333
# 59  0.157675  0.974733  0.333829      0.929333

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'g', label = 'train loss')
loss_ax.plot(history.history['val_loss'], 'y', label = 'val loss')

acc_ax.plot(history.history['accuracy'], 'b', label = 'train accuracy')
acc_ax.plot(history.history['val_accuracy'], 'r', label = 'val accuracy')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')


loss_ax.legend(loc = 'upper left')
acc_ax.legend(loc = 'lower left')

plt.show()

# %%
acc = model.evaluate(x_train, y_train)
print(acc)
# Out:
# 2022-12-04 16:33:10.762122: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 2257920000 exceeds 10% of free system memory.
# 2022-12-04 16:33:14.024086: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 2257920000 exceeds 10% of free system memory.
# 469/469 [==============================] - 8s 17ms/step - loss: 0.1232 - accuracy: 0.9717
# [0.12322897464036942, 0.9717333316802979]

# %%
y_pred=model.predict(x_test)
len(y_pred)
# Out:
# 3000

# %%
def acc(_test, _y):
    Tp = 0
    Negative = 0
    cnt = 0
    for num in _test:
        if np.argmax(num) == _y[cnt]:
            Tp += 1
        else:
            Negative +=1
        cnt += 1
    print("맞춘 갯수: ", Tp)
    print("틀린 갯수: ", Negative)
    print("정확도: ", Tp/(Tp+Negative)*100, "%")

# %%
acc(y_pred, y_test)
# Out:
# 맞춘 갯수:  2781
# 틀린 갯수:  219
# 정확도:  92.7 %

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis = -1)

accuracy_score(y_test, y_pred)
# Out:
# 0.927

# %%
from sklearn.metrics import confusion_matrix, classification_report

# confustion matrix(y_test, y_pred)
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.97      0.86      0.91       200\n           1       0.93      0.96      0.95       200\n           2       0.91      0.99      0.95       200\n           3       0.99      0.92      0.96       200\n           4       0.83      0.90      0.87       200\n           5       0.94      0.92      0.93       200\n           6       0.98      0.80      0.88       200\n           7       0.97      0.97      0.97       200\n           8       0.94      0.98      0.96       200\n           9       0.83      0.95      0.88       200\n          10       0.99      0.91      0.95       200\n          11       0.94      0.86      0.90       200\n          12       0.87      0.97      0.92       200\n          13       0.90      0.92      0.91       200\n          14       0.96      0.98      0.97       200\n\n    accuracy                           0.93      3000\n   macro avg       0.93      0.93      0.93      3000\nweighted avg       0.93      0.93      0.93      3000\n'

# %%
def plot_roc_curve(fper, tper):
    plt.plot(fper, tper, color='red', label='ROC')
    plt.plot([0,1],[0,1],color='green',linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel("True Positive Rate")
    plt.title("Receiver Operating Characteristic Curve")
    plt.legend()
    plt.show()

# %%
from sklearn.metrics import roc_curve

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=-1)
print(y_pred)
fper, tper, thresholds = roc_curve(y_test, y_pred, pos_label=14)
plot_roc_curve(fper, tper)
# Out:
# [ 0  0  0 ... 14 14 14]

# %%
classes = list(x_test)
test_classes = [classes[x] for x in y_test]

pred = tf.argmax(model.predict(x_test),axis=1)
pred_classes = [classes[x] for x in pred]

# %%
from sklearn.metrics import confusion_matrix
prediction = confusion_matrix(y_test, y_pred)

# %%
import seaborn as sns
m = pd.DataFrame(prediction, index=[i for i in range(len(prediction[0]))], columns = [i for i in range(len(prediction[0]))])
plt.figure(figsize=(15,15))
plt.title("confusion matrix")
cnn_matric = sns.heatmap(m, annot=True, fmt='d', cmap='Blues')
cnn_matric.set_xlabel('Real')
cnn_matric.set_ylabel('Predict')
# Out:
# Text(114.0, 0.5, 'Predict')
