# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_path = "../input/vegetable-image-dataset/Vegetable Images/train"
validation_path = "../input/vegetable-image-dataset/Vegetable Images/validation"
test_path = "../input/vegetable-image-dataset/Vegetable Images/test"

# %%
from matplotlib import image
from PIL import Image

def Load_Images(path):
    folders=os.listdir(path)
    data = []
    label = []
    print(folders)
    for i in folders:
        c=0
        images=os.listdir(path + '/' + i)
        for j in images:
            c+=1
            im=Image.open(path + '/' + i + '/' + j).convert('RGB')
            im=im.resize((224,224), image.NEAREST)
            #print(im.size)
            ar=np.array(im)
            #print(ar.shape)
            data.append(ar)
            if i=='Bean':
                label.append(i)
            elif i=='Bitter_Gourd':
                label.append(i)
            elif i=='Bottle':
                label.append(i)
            elif i=='Brinjal':
                label.append(i)
            elif i=='Broccoli':
                label.append(i)
            elif i=='Cabbage':
                label.append(i)
            elif i=='Capsicum':
                label.append(i)
            elif i=='Carrot':
                label.append(i)
            elif i=='Cauliflower':
                label.append(i)
            elif i=='Cucumber':
                label.append(i)
            elif i=='Papaya':
                label.append(i)
            elif i=='Potato':
                label.append(i)
            elif i=='Pumpkin':
                label.append(i)
            elif i=='Radish':
                label.append(i)
            else:
                label.append(i)
            #label.append(i)
            #print(c)
    t=pd.factorize(np.array(label))
    print(t)
    tgt=t[0]
    return np.array(data), tgt

# %%
x_train, y_train = Load_Images(train_path)
y_train = pd.Series(y_train)
print(x_train.shape)
# Out:
# ['Broccoli', 'Capsicum', 'Bottle_Gourd', 'Radish', 'Tomato', 'Brinjal', 'Pumpkin', 'Carrot', 'Papaya', 'Cabbage', 'Bitter_Gourd', 'Cauliflower', 'Bean', 'Cucumber', 'Potato']
# (array([ 0,  0,  0, ..., 14, 14, 14]), array(['Broccoli', 'Capsicum', 'Bottle_Gourd', 'Radish', 'Tomato',
#        'Brinjal', 'Pumpkin', 'Carrot', 'Papaya', 'Cabbage',
#        'Bitter_Gourd', 'Cauliflower', 'Bean', 'Cucumber', 'Potato'],
#       dtype=object))
# (15000, 224, 224, 3)

# %%
x_valid, y_valid = Load_Images(validation_path)
y_valid = pd.Series(y_valid)
print(x_valid.shape)
# Out:
# ['Broccoli', 'Capsicum', 'Bottle_Gourd', 'Radish', 'Tomato', 'Brinjal', 'Pumpkin', 'Carrot', 'Papaya', 'Cabbage', 'Bitter_Gourd', 'Cauliflower', 'Bean', 'Cucumber', 'Potato']
# (array([ 0,  0,  0, ..., 14, 14, 14]), array(['Broccoli', 'Capsicum', 'Bottle_Gourd', 'Radish', 'Tomato',
#        'Brinjal', 'Pumpkin', 'Carrot', 'Papaya', 'Cabbage',
#        'Bitter_Gourd', 'Cauliflower', 'Bean', 'Cucumber', 'Potato'],
#       dtype=object))
# (3000, 224, 224, 3)

# %%
name_list = ['Bean', 'Bitter_Gourd', 'Bottle_Gourd', 'Brinjal', 'Broccoli', 'Cabbage', 'Capsicum', 'Carrot', 'Cauliflower', 'Cucumber', 'Papaya', 'Potato', 'Pumpkin', 'Radish', 'Tomato']
index = 0
for i in name_list:
    y_train = y_train.replace(i, index)
    y_valid = y_valid.replace(i, index)
    index += 1

# %%
x_test, y_test = Load_Images(test_path)
y_test = pd.Series(y_test)
y_test = y_test.replace("Bean", 0)
y_test = y_test.replace("Bitter_Gourd", 1)
y_test = y_test.replace("Bottle_Gourd", 2)
y_test = y_test.replace("Brinjal", 3)
y_test = y_test.replace("Broccoli", 4)
y_test = y_test.replace("Cabbage", 5)
y_test = y_test.replace("Capsicum", 6)
y_test = y_test.replace("Carrot", 7)
y_test = y_test.replace("Cauliflower", 8)
y_test = y_test.replace("Cucumber", 9)
y_test = y_test.replace("Papaya", 10)
y_test = y_test.replace("Potato", 11)
y_test = y_test.replace("Pumpkin", 12)
y_test = y_test.replace("Radish", 13)
y_test = y_test.replace("Tomato", 14)
# Out:
# ['Broccoli', 'Capsicum', 'Bottle_Gourd', 'Radish', 'Tomato', 'Brinjal', 'Pumpkin', 'Carrot', 'Papaya', 'Cabbage', 'Bitter_Gourd', 'Cauliflower', 'Bean', 'Cucumber', 'Potato']
# (array([ 0,  0,  0, ..., 14, 14, 14]), array(['Broccoli', 'Capsicum', 'Bottle_Gourd', 'Radish', 'Tomato',
#        'Brinjal', 'Pumpkin', 'Carrot', 'Papaya', 'Cabbage',
#        'Bitter_Gourd', 'Cauliflower', 'Bean', 'Cucumber', 'Potato'],
#       dtype=object))

# %%
# # 1. Train Set

# # rescale: 0과 1사이로 값을 변경함
# # ImageDataGenerator: 데이터 증식(augmentation)
# # ImageDataGenerator는 Noise삽입, 색상, 밝기 변형 등을 활용하여 실시간으로 데이터 증강을 사용하고, 
# # 텐서 이미지 데이터 배치를 생성하여 데이터 학습의 정확도를 높이는 역할을 한다.

# train_gen = ImageDataGenerator(rescale = 1./255.0) # Normalise the data

# # flow() 또는 flow_from_directory() 또는 flow_from_dataframe() 함수로 Numpy Array Iterator 객체를 만들어줌. 
# # 이 때, X(image) array, Y(label) array, 배치 사이즈, 데이터 셔플 유무를 설정.

# # 메타 데이터:  이미지 데이터 파일(jpg, jpeg)들과 해당 이미지들이 무슨 이미지를 나타내는지 텍스트로 표현한 문자열(cat, dog와 같은 문자열들)
# # flow_from_directory(): 메타 데이터가 담긴 디렉토리
# # target_size : 추후에 설계할 모델에 들어갈 인풋 이미지 사이즈 중 Width, Height를 입력
# # batch_size : 이미지 데이터 원본 소스에서 한 번에 얼마만큼의 이미지 데이터를 가져올 것인지
# # class_mode
# #    'categorical' : 'categorical_crossentropy' 처럼 멀티-레이블 클래스인데, 원-핫 인코딩된 형태
# #    'sparse' : 'sparse_categorical_crossentropy' 처럼 멀티-레이블 클래스인데, 레이블 인코딩된 형태
# #    'binary' : 'binary_crossentropy' 처럼 이진 분류 클래스로, 0 또는 1인 형태

# train_image_generator = train_gen.flow_from_directory(
#                                             train_path,
#                                             target_size=(224, 224),
#                                             batch_size=32,
#                                             class_mode='categorical')

# # 2. Validation Set
# val_gen = ImageDataGenerator(rescale = 1.0/255.0) # Normalise the data
# val_image_generator = train_gen.flow_from_directory(
#                                             validation_path,
#                                             target_size=(224, 224),
#                                             batch_size=32,
#                                             class_mode='categorical')

# # 3. Test Set
# test_gen = ImageDataGenerator(rescale = 1.0/255.0) # Normalise the data
# test_image_generator = train_gen.flow_from_directory(
#                                             test_path,
#                                             target_size=(224, 224),
#                                             batch_size=32,
#                                             class_mode='categorical')

# %%
# from keras.preprocessing import image
# # Call the function
# image_categories = os.listdir('../input/vegetable-image-dataset/Vegetable Images/train')

# def plot_images(image_categories):
#     # Create a figure
#     plt.figure(figsize=(12, 12))
#     for i, cat in enumerate(image_categories):
#         # Load images for the ith category
#         image_path = train_path + '/' + cat
#         images_in_folder = os.listdir(image_path)
#         first_image_of_folder = images_in_folder[0]
#         first_image_path = image_path + '/' + first_image_of_folder
#         img = image.load_img(first_image_path)
#         img_arr = image.img_to_array(img)/255.0

#         # Create Subplot and plot the images
#         plt.subplot(4, 4, i+1)
#         plt.imshow(img_arr)
#         plt.title(cat)
#         plt.axis('off')

#     plt.show()

# # Call the function
# plot_images(image_categories)

# %%
# from keras.models import Sequential 
# from keras.layers import Conv2D,Dense, Flatten, AveragePooling2D, Dropout 
# model = Sequential()

# model.add(Conv2D(6, kernel_size=(3, 3), activation='tanh', input_shape=x_train.shape[1:]))
# model.add(AveragePooling2D())
# Dropout(0.2)

# model.add(Conv2D(32, kernel_size=(3,3), activation='tanh'))
# model.add(AveragePooling2D())

# model.add(Conv2D(64, kernel_size=(3,3),activation='tanh'))

# model.add(Flatten())

# model.add(Dense(15, activation = 'softmax'))
# model.summary()

# %%
import tensorflow as tf
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)

# %%
from keras.models import Sequential 
from keras.layers import Input,Conv2D, Dense, Flatten, MaxPooling2D, Dropout, BatchNormalization, Activation, ZeroPadding2D
model = Sequential()

# 논문을 바탕으로 모델 구축함.
# 그러나 Computing power 한계로 인해 변경을 좀 했음.
# modeling
# input_shape = (224, 224, 3)  # 논문에서 제시된 shape

img_shape = x_train.shape[1:]

# CONV
# 레이어 1
model.add(Conv2D(filters=96, kernel_size=11, activation='relu', strides=4, padding='same',input_shape=img_shape))
model.add(MaxPooling2D((3,3), strides=2)) # overlapped pooling
model.add(BatchNormalization())

# 레이어 2
model.add(Conv2D(filters=256, kernel_size=5, activation='relu', strides=1, padding='same'))
model.add(MaxPooling2D((3,3), strides=2))
model.add(BatchNormalization())

# 레이어 3
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(filters=384, kernel_size=3, activation='relu', strides=1, padding='same'))

# 레이어 4
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(filters=384, kernel_size=3, activation='relu', strides=1, padding='same'))

# 레이어 5
model.add(ZeroPadding2D((1,1)))
model.add(Conv2D(filters=256, kernel_size=3, activation='relu', strides=1, padding='same'))
model.add(MaxPooling2D((3,3), strides=2))

# FC
# 레이어 6
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))  # 논문 parameter 0.5 이용함.

# 레이어 7
model.add(Dense(4096, activation='relu'))
model.add(Dropout(0.5))

# 레이어 8
model.add(Dense(1000, activation='softmax'))
model.summary()
# Out:
# 2022-12-04 16:38:56.385194: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:38:56.386106: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:38:56.769446: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:38:56.770339: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:38:56.771155: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:38:56.771929: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:38:56.773032: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-04 16:38:57.007307: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:38:57.008134: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:38:57.008871: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:38:57.009568: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:38:57.010220: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:38:57.010886: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:39:01.228456: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:39:01.229433: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:39:01.230183: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:39:01.230927: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:39:01.231660: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:39:01.232304: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2022-12-04 16:39:01.236312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-04 16:39:01.237104: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 56, 56, 96)        34944
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 27, 27, 96)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 27, 27, 96)        384
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 27, 27, 256)       614656
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 256)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 13, 13, 256)       1024
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 15, 15, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 384)       885120
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 17, 17, 384)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 17, 17, 384)       1327488
# _________________________________________________________________
# zero_padding2d_2 (ZeroPaddin (None, 19, 19, 384)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 19, 19, 256)       884992
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 20736)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              84938752
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000)              4097000
# =================================================================
# Total params: 109,565,672
# Trainable params: 109,564,968
# Non-trainable params: 704
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping
history = model.fit(x_train, y_train, epochs=100,  validation_data=(x_valid, y_valid))
# Out:
# 2022-12-04 16:39:01.920545: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 2257920000 exceeds 10% of free system memory.
# 2022-12-04 16:39:04.409105: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 2257920000 exceeds 10% of free system memory.
# 2022-12-04 16:39:06.204312: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-12-04 16:39:08.896874: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 469/469 [==============================] - ETA: 0s - loss: 1.8367 - accuracy: 0.4549
# 2022-12-04 16:39:48.320555: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 451584000 exceeds 10% of free system memory.
# 2022-12-04 16:39:48.873493: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 451584000 exceeds 10% of free system memory.
# 469/469 [==============================] - 45s 64ms/step - loss: 1.8367 - accuracy: 0.4549 - val_loss: 2.4499 - val_accuracy: 0.3267
# Epoch 2/100
# 469/469 [==============================] - 29s 61ms/step - loss: 0.8646 - accuracy: 0.7352 - val_loss: 1.1698 - val_accuracy: 0.6660
# Epoch 3/100
# 469/469 [==============================] - 29s 62ms/step - loss: 0.6516 - accuracy: 0.8033 - val_loss: 1.0090 - val_accuracy: 0.6830
# Epoch 4/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.5857 - accuracy: 0.8287 - val_loss: 0.5103 - val_accuracy: 0.8377
# Epoch 5/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.4510 - accuracy: 0.8715 - val_loss: 0.3619 - val_accuracy: 0.8910
# Epoch 6/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.3894 - accuracy: 0.8867 - val_loss: 0.6134 - val_accuracy: 0.8193
# Epoch 7/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.3397 - accuracy: 0.9065 - val_loss: 0.6550 - val_accuracy: 0.8037
# Epoch 8/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.3396 - accuracy: 0.9095 - val_loss: 0.7411 - val_accuracy: 0.8047
# Epoch 9/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.3295 - accuracy: 0.9111 - val_loss: 0.3948 - val_accuracy: 0.8957
# Epoch 10/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.3185 - accuracy: 0.9168 - val_loss: 0.4415 - val_accuracy: 0.8803
# Epoch 11/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2576 - accuracy: 0.9309 - val_loss: 0.3606 - val_accuracy: 0.9007
# Epoch 12/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2844 - accuracy: 0.9276 - val_loss: 1.2175 - val_accuracy: 0.7113
# Epoch 13/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2510 - accuracy: 0.9346 - val_loss: 0.5299 - val_accuracy: 0.8630
# Epoch 14/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2109 - accuracy: 0.9451 - val_loss: 0.2604 - val_accuracy: 0.9400
# Epoch 15/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2291 - accuracy: 0.9428 - val_loss: 0.3767 - val_accuracy: 0.9140
# Epoch 16/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2129 - accuracy: 0.9482 - val_loss: 1.2197 - val_accuracy: 0.7413
# Epoch 17/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2581 - accuracy: 0.9378 - val_loss: 0.7845 - val_accuracy: 0.8373
# Epoch 18/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2466 - accuracy: 0.9430 - val_loss: 0.2713 - val_accuracy: 0.9333
# Epoch 19/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2215 - accuracy: 0.9488 - val_loss: 2.9179 - val_accuracy: 0.7067
# Epoch 20/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2472 - accuracy: 0.9449 - val_loss: 0.5535 - val_accuracy: 0.8987
# Epoch 21/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2657 - accuracy: 0.9455 - val_loss: 0.2882 - val_accuracy: 0.9310
# Epoch 22/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1808 - accuracy: 0.9610 - val_loss: 0.4034 - val_accuracy: 0.9227
# Epoch 23/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1944 - accuracy: 0.9584 - val_loss: 0.5362 - val_accuracy: 0.9030
# Epoch 24/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2096 - accuracy: 0.9547 - val_loss: 0.4443 - val_accuracy: 0.9163
# Epoch 25/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2310 - accuracy: 0.9527 - val_loss: 0.5406 - val_accuracy: 0.8607
# Epoch 26/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1673 - accuracy: 0.9626 - val_loss: 0.2093 - val_accuracy: 0.9577
# Epoch 27/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1627 - accuracy: 0.9633 - val_loss: 0.3044 - val_accuracy: 0.9370
# Epoch 28/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1785 - accuracy: 0.9627 - val_loss: 1.1667 - val_accuracy: 0.8370
# Epoch 29/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2175 - accuracy: 0.9561 - val_loss: 0.2370 - val_accuracy: 0.9417
# Epoch 30/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2000 - accuracy: 0.9605 - val_loss: 0.2168 - val_accuracy: 0.9430
# Epoch 31/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1654 - accuracy: 0.9651 - val_loss: 0.8130 - val_accuracy: 0.8130
# Epoch 32/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1555 - accuracy: 0.9675 - val_loss: 0.2228 - val_accuracy: 0.9533
# Epoch 33/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2062 - accuracy: 0.9605 - val_loss: 0.6571 - val_accuracy: 0.8680
# Epoch 34/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2543 - accuracy: 0.9513 - val_loss: 0.9787 - val_accuracy: 0.7927
# Epoch 35/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1391 - accuracy: 0.9683 - val_loss: 0.2285 - val_accuracy: 0.9597
# Epoch 36/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1889 - accuracy: 0.9635 - val_loss: 0.3582 - val_accuracy: 0.9327
# Epoch 37/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1906 - accuracy: 0.9633 - val_loss: 1.2999 - val_accuracy: 0.8490
# Epoch 38/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2034 - accuracy: 0.9638 - val_loss: 0.2730 - val_accuracy: 0.9577
# Epoch 39/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1975 - accuracy: 0.9651 - val_loss: 0.3436 - val_accuracy: 0.9333
# Epoch 40/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1366 - accuracy: 0.9713 - val_loss: 0.2554 - val_accuracy: 0.9603
# Epoch 41/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1619 - accuracy: 0.9729 - val_loss: 0.5877 - val_accuracy: 0.9163
# Epoch 42/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1705 - accuracy: 0.9688 - val_loss: 0.2084 - val_accuracy: 0.9610
# Epoch 43/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1728 - accuracy: 0.9687 - val_loss: 0.2626 - val_accuracy: 0.9547
# Epoch 44/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2007 - accuracy: 0.9666 - val_loss: 0.1913 - val_accuracy: 0.9647
# Epoch 45/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1609 - accuracy: 0.9725 - val_loss: 0.3124 - val_accuracy: 0.9590
# Epoch 46/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1406 - accuracy: 0.9755 - val_loss: 0.2574 - val_accuracy: 0.9500
# Epoch 47/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1884 - accuracy: 0.9688 - val_loss: 0.2837 - val_accuracy: 0.9460
# Epoch 48/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1895 - accuracy: 0.9677 - val_loss: 0.2655 - val_accuracy: 0.9550
# Epoch 49/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1512 - accuracy: 0.9703 - val_loss: 0.2504 - val_accuracy: 0.9543
# Epoch 50/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1579 - accuracy: 0.9724 - val_loss: 0.3905 - val_accuracy: 0.9187
# Epoch 51/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1650 - accuracy: 0.9729 - val_loss: 0.1888 - val_accuracy: 0.9637
# Epoch 52/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1879 - accuracy: 0.9680 - val_loss: 0.3726 - val_accuracy: 0.9477
# Epoch 53/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1445 - accuracy: 0.9759 - val_loss: 0.2242 - val_accuracy: 0.9607
# Epoch 54/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1737 - accuracy: 0.9700 - val_loss: 0.6612 - val_accuracy: 0.9000
# Epoch 55/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2290 - accuracy: 0.9637 - val_loss: 0.1794 - val_accuracy: 0.9657
# Epoch 56/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1852 - accuracy: 0.9706 - val_loss: 0.3500 - val_accuracy: 0.9323
# Epoch 57/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1809 - accuracy: 0.9700 - val_loss: 0.5144 - val_accuracy: 0.9110
# Epoch 58/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1411 - accuracy: 0.9774 - val_loss: 0.2771 - val_accuracy: 0.9473
# Epoch 59/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1541 - accuracy: 0.9747 - val_loss: 0.4461 - val_accuracy: 0.9160
# Epoch 60/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1419 - accuracy: 0.9759 - val_loss: 0.3625 - val_accuracy: 0.9527
# Epoch 61/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1689 - accuracy: 0.9711 - val_loss: 0.2746 - val_accuracy: 0.9497
# Epoch 62/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1566 - accuracy: 0.9757 - val_loss: 0.3756 - val_accuracy: 0.9470
# Epoch 63/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1640 - accuracy: 0.9751 - val_loss: 0.3422 - val_accuracy: 0.9573
# Epoch 64/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1555 - accuracy: 0.9765 - val_loss: 0.8513 - val_accuracy: 0.8790
# Epoch 65/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1785 - accuracy: 0.9717 - val_loss: 0.2290 - val_accuracy: 0.9517
# Epoch 66/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.0979 - accuracy: 0.9840 - val_loss: 0.5764 - val_accuracy: 0.9300
# Epoch 67/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1992 - accuracy: 0.9716 - val_loss: 0.3482 - val_accuracy: 0.9620
# Epoch 68/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2063 - accuracy: 0.9717 - val_loss: 0.1952 - val_accuracy: 0.9663
# Epoch 69/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1415 - accuracy: 0.9776 - val_loss: 0.3480 - val_accuracy: 0.9527
# Epoch 70/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1348 - accuracy: 0.9795 - val_loss: 0.2990 - val_accuracy: 0.9577
# Epoch 71/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1389 - accuracy: 0.9795 - val_loss: 0.2474 - val_accuracy: 0.9667
# Epoch 72/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.1954 - accuracy: 0.9704 - val_loss: 0.3189 - val_accuracy: 0.9490
# Epoch 73/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1114 - accuracy: 0.9837 - val_loss: 0.4397 - val_accuracy: 0.9630
# Epoch 74/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1884 - accuracy: 0.9754 - val_loss: 0.3854 - val_accuracy: 0.9573
# Epoch 75/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1163 - accuracy: 0.9840 - val_loss: 0.8912 - val_accuracy: 0.9203
# Epoch 76/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2084 - accuracy: 0.9749 - val_loss: 0.9437 - val_accuracy: 0.9563
# Epoch 77/100
# 469/469 [==============================] - 30s 64ms/step - loss: 0.2507 - accuracy: 0.9743 - val_loss: 0.5896 - val_accuracy: 0.9417
# Epoch 78/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2260 - accuracy: 0.9713 - val_loss: 0.4617 - val_accuracy: 0.9477
# Epoch 79/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1639 - accuracy: 0.9789 - val_loss: 0.5828 - val_accuracy: 0.9363
# Epoch 80/100
# 469/469 [==============================] - 29s 63ms/step - loss: 0.1821 - accuracy: 0.9763 - val_loss: 0.2285 - val_accuracy: 0.9657
# Epoch 81/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1394 - accuracy: 0.9817 - val_loss: 0.1815 - val_accuracy: 0.9740
# Epoch 82/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.0975 - accuracy: 0.9885 - val_loss: 0.3961 - val_accuracy: 0.9557
# Epoch 83/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1569 - accuracy: 0.9771 - val_loss: 0.4326 - val_accuracy: 0.9453
# Epoch 84/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2417 - accuracy: 0.9738 - val_loss: 0.2942 - val_accuracy: 0.9693
# Epoch 85/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1607 - accuracy: 0.9790 - val_loss: 0.6620 - val_accuracy: 0.9307
# Epoch 86/100
# 469/469 [==============================] - 29s 63ms/step - loss: 0.1397 - accuracy: 0.9817 - val_loss: 0.4484 - val_accuracy: 0.9660
# Epoch 87/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2119 - accuracy: 0.9760 - val_loss: 1.1397 - val_accuracy: 0.8907
# Epoch 88/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1875 - accuracy: 0.9757 - val_loss: 0.4379 - val_accuracy: 0.9687
# Epoch 89/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1640 - accuracy: 0.9795 - val_loss: 0.7131 - val_accuracy: 0.9387
# Epoch 90/100
# 469/469 [==============================] - 29s 63ms/step - loss: 0.2298 - accuracy: 0.9745 - val_loss: 0.4798 - val_accuracy: 0.9663
# Epoch 91/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2021 - accuracy: 0.9763 - val_loss: 0.5587 - val_accuracy: 0.9647
# Epoch 92/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1125 - accuracy: 0.9842 - val_loss: 0.4228 - val_accuracy: 0.9640
# Epoch 93/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1010 - accuracy: 0.9885 - val_loss: 1.5248 - val_accuracy: 0.9020
# Epoch 94/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1634 - accuracy: 0.9789 - val_loss: 0.2527 - val_accuracy: 0.9660
# Epoch 95/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1715 - accuracy: 0.9795 - val_loss: 0.4602 - val_accuracy: 0.9563
# Epoch 96/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2308 - accuracy: 0.9749 - val_loss: 0.5969 - val_accuracy: 0.9497
# Epoch 97/100
# 469/469 [==============================] - 29s 63ms/step - loss: 0.2603 - accuracy: 0.9747 - val_loss: 0.5760 - val_accuracy: 0.9320
# Epoch 98/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.2106 - accuracy: 0.9759 - val_loss: 0.3773 - val_accuracy: 0.9583
# Epoch 99/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1448 - accuracy: 0.9828 - val_loss: 0.3998 - val_accuracy: 0.9677
# Epoch 100/100
# 469/469 [==============================] - 30s 63ms/step - loss: 0.1872 - accuracy: 0.9798 - val_loss: 0.6342 - val_accuracy: 0.9633

# %%
# hist = model.fit(train_image_generator, 
#                  epochs=20, 
#                  verbose=1, 
#                  validation_data=val_image_generator, 
#                  steps_per_epoch = 15000//24, 
#                  validation_steps = 3000//24)

# h = hist.history
# plt.style.use('ggplot')
# plt.figure(figsize=(10, 5))
# plt.plot(h['loss'], c='red', label='Training Loss')
# plt.plot(h['val_loss'], c='red', linestyle='--', label='Validation Loss')
# plt.plot(h['accuracy'], c='blue', label='Training Accuracy')
# plt.plot(h['val_accuracy'], c='blue', linestyle='--', label='Validation Accuracy')
# plt.xlabel("Number of Epochs")
# plt.legend(loc='best')
# plt.show()

# model.evaluate(test_image_generator)

# %%
history_df = pd.DataFrame(history.history)
history_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.836671  0.454933  2.449926      0.326667
# 1   0.864587  0.735200  1.169805      0.666000
# 2   0.651591  0.803267  1.009008      0.683000
# 3   0.585653  0.828667  0.510271      0.837667
# 4   0.450970  0.871533  0.361896      0.891000
# ..       ...       ...       ...           ...
# 95  0.230752  0.974933  0.596900      0.949667
# 96  0.260298  0.974733  0.576029      0.932000
# 97  0.210598  0.975933  0.377318      0.958333
# 98  0.144804  0.982800  0.399807      0.967667
# 99  0.187188  0.979800  0.634178      0.963333
#
# [100 rows x 4 columns]

# %%
fig, loss_ax = plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(history.history['loss'], 'g', label = 'train loss')
loss_ax.plot(history.history['val_loss'], 'y', label = 'val loss')

acc_ax.plot(history.history['accuracy'], 'b', label = 'train accuracy')
acc_ax.plot(history.history['val_accuracy'], 'r', label = 'val accuracy')

loss_ax.set_xlabel('epoch')
loss_ax.set_ylabel('loss')
acc_ax.set_ylabel('accuracy')


loss_ax.legend(loc = 'upper left')
acc_ax.legend(loc = 'lower left')

plt.show()

# %%
acc = model.evaluate(x_train, y_train)
print(acc)
# Out:
# 2022-12-04 17:28:50.148325: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 2257920000 exceeds 10% of free system memory.
# 469/469 [==============================] - 8s 17ms/step - loss: 0.0442 - accuracy: 0.9921
# [0.04420069605112076, 0.9920666813850403]

# %%
y_pred=model.predict(x_test)
len(y_pred)
# Out:
# 3000

# %%
def acc(_test, _y):
    Tp = 0
    Negative = 0
    cnt = 0
    for num in _test:
        if np.argmax(num) == _y[cnt]:
            Tp += 1
        else:
            Negative +=1
        cnt += 1
    print("맞춘 갯수: ", Tp)
    print("틀린 갯수: ", Negative)
    print("정확도: ", Tp/(Tp+Negative)*100, "%")

# %%
acc(y_pred, y_test)
# Out:
# 맞춘 갯수:  2886
# 틀린 갯수:  114
# 정확도:  96.2 %

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis = -1)

accuracy_score(y_test, y_pred)
# Out:
# 0.962

# %%
from sklearn.metrics import confusion_matrix, classification_report

# confustion matrix(y_test, y_pred)
classification_report(y_test, y_pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.98      0.94      0.96       200\n           1       0.96      0.99      0.98       200\n           2       0.94      0.99      0.97       200\n           3       0.99      0.98      0.99       200\n           4       0.96      0.92      0.94       200\n           5       0.95      0.97      0.96       200\n           6       0.98      0.89      0.93       200\n           7       0.96      1.00      0.98       200\n           8       0.98      0.98      0.98       200\n           9       0.91      0.95      0.93       200\n          10       0.97      0.94      0.96       200\n          11       0.98      0.92      0.95       200\n          12       0.91      0.98      0.95       200\n          13       0.99      0.98      0.99       200\n          14       0.98      0.98      0.98       200\n\n    accuracy                           0.96      3000\n   macro avg       0.96      0.96      0.96      3000\nweighted avg       0.96      0.96      0.96      3000\n'

# %%
def plot_roc_curve(fper, tper):
    plt.plot(fper, tper, color='red', label='ROC')
    plt.plot([0,1],[0,1],color='green',linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel("True Positive Rate")
    plt.title("Receiver Operating Characteristic Curve")
    plt.legend()
    plt.show()

# %%
from sklearn.metrics import roc_curve

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=-1)
print(y_pred)
fper, tper, thresholds = roc_curve(y_test, y_pred, pos_label=14)
plot_roc_curve(fper, tper)
# Out:
# [ 0  0  0 ... 14 14 14]

# %%
classes = list(x_test)
test_classes = [classes[x] for x in y_test]

pred = tf.argmax(model.predict(x_test),axis=1)
pred_classes = [classes[x] for x in pred]

# %%
from sklearn.metrics import confusion_matrix
prediction = confusion_matrix(y_test, y_pred)

# %%
import seaborn as sns
m = pd.DataFrame(prediction, index=[i for i in range(len(prediction[0]))], columns = [i for i in range(len(prediction[0]))])
plt.figure(figsize=(15,15))
plt.title("confusion matrix")
cnn_matric = sns.heatmap(m, annot=True, fmt='d', cmap='Blues')
cnn_matric.set_xlabel('Real')
cnn_matric.set_ylabel('Predict')
# Out:
# Text(114.0, 0.5, 'Predict')
